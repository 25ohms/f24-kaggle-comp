# %% [markdown]
# Importing modules + training data

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing, linear_model, model_selection, metrics, neighbors, ensemble
import numpy as np

# your files might be in "Shared with me" instead of "My Drive", or you could just manually upload to the Colab and remove the "drive/My Drive/STAT441 Kaggle/" part entirely
df_ed_train = pd.read_csv("./module_Education_train_set.csv")
df_hh_train = pd.read_csv("./module_HouseholdInfo_train_set.csv")
y_train = pd.read_csv("./module_SubjectivePoverty_train_set.csv")

df_ed_test = pd.read_csv("./module_Education_test_set.csv")
df_hh_test = pd.read_csv("./module_HouseholdInfo_test_set.csv")

# %% [markdown]
# Combining DFs

# %%
#adding the 'psu_hh_idcode' column for future merging
df_ed_train['psu_hh_idcode'] = ['_'.join([str(int(row['psu'])),str(int(row['hh'])),str(int(row['idcode']))]) for index, row in df_ed_train.iterrows()]
df_ed_train.drop(['hh', 'idcode'], axis=1, inplace=True)

df_hh_train['psu_hh_idcode'] = ['_'.join([str(int(row['psu'])),str(int(row['hh'])),str(int(row['idcode']))]) for index, row in df_hh_train.iterrows()]
df_hh_train.drop(['hh', 'idcode'], axis=1, inplace=True)

df_ed_test['psu_hh_idcode'] = ['_'.join([str(int(row['psu'])),str(int(row['hh'])),str(int(row['idcode']))]) for index, row in df_ed_test.iterrows()]
df_ed_test.drop(['hh', 'idcode'], axis=1, inplace=True)


df_hh_test['psu_hh_idcode'] = ['_'.join([str(int(row['psu'])),str(int(row['hh'])),str(int(row['idcode']))]) for index, row in df_hh_test.iterrows()]
df_hh_test.drop(['hh', 'idcode'], axis=1, inplace=True)

# combining the subjective_poverty_n columns into a single column
y_train = y_train[y_train['psu_hh_idcode'].isin(df_ed_train['psu_hh_idcode'])]
sp_onehot = y_train.drop(columns=['psu_hh_idcode'])
y_train['subjective_poverty'] = pd.from_dummies(sp_onehot)
y_train['subjective_poverty'] = [int(x[19:]) for x in y_train['subjective_poverty']]
y_train.drop(columns=['subjective_poverty_' + str(i) for i in range(1,11)], inplace=True)

df_ed_train.set_index('psu_hh_idcode', inplace=True)
df_hh_train.set_index('psu_hh_idcode', inplace=True)
df_ed_test.set_index('psu_hh_idcode', inplace=True)
df_hh_test.set_index('psu_hh_idcode', inplace=True)

y_train.set_index('psu_hh_idcode', inplace=True)

#MAYBE REMOVE THIS PART:
# All other columns in the education test set are almost 99% NA
# Theoretically including all the rest of the columns should only give at most a score improvement of ~0.023
# since it only applies to 1% of the training data (and just giving every option a 0.1 chance is a log loss of 2.3)
##### df_ed_train = df_ed_train[['q01', 'q02', 'q03', 'q04', 'q05', 'q06', 'q07', 'Q08', 'Q11', 'Q14', 'Q17', 'Q18', 'Q19']]
df_ed_train['set'] = 'train'
##### df_ed_test = df_ed_test[['q01', 'q02', 'q03', 'q04', 'q05', 'q06', 'q07', 'Q08', 'Q11', 'Q14', 'Q17', 'Q18', 'Q19']]
df_ed_test['set'] = 'test'

# combining training and test sets
df_ed = pd.concat([df_ed_train, df_ed_test])
df_hh = pd.concat([df_hh_train, df_hh_test])

df = df_hh.join(df_ed, lsuffix="_hh", how='inner')

# %% [markdown]
# Filling in NAs

# %%
###df['q07'].fillna(0) # q07 in education is NA => never went to school => 0 years of preschool


def highest_education(index):
  row = df_ed.loc[index]
  if row['q03'] == 2 or row['q06'] == 0:
    return 1 # no education
  elif row['q06'] == 1:
    return 2 # primary 4/5
  elif row['q06'] == 2 and row['q04'] == 1:
    return 3 # primary 7/8/9
  elif row['q04'] == 2 and row['q06'] < 3:
    return 4 # some secondary
  elif row['q06'] == 3 and row['q04'] == 2:
    return 5 # finished secondary
  elif row['q06'] < 4 and row['q04'] in [3,4,5]:
    return 6 # some vocational (pretty sure "Technicum" is  a type of vocational)
  elif row['q06'] in [4,5,6] and row['q04'] < 6:
    return 7 # finished vocational
  elif row['q06'] < 7 and row['q04'] >= 6:
    return 8 # some university
  elif row['q06'] in [7,8,9]:
    return 9 # finished university
  else:
    return 10 # Post university



for index, row in df.iterrows():
  if row['q11'] == 1:
    mother = '_'.join(index.split('_')[:-1] + [str(int(row['q12']))])
    if mother in df_ed.index:
        row['q13'] = highest_education(mother)
    elif mother in df_ed.index:
        row['q13'] = highest_education(mother)
    row['q14'] = 1
    if mother in df_hh.index:
        row['q16'] = df_hh.loc[mother]['q05y']

  if row['q17'] == 1:
    father = '_'.join(index.split('_')[:-1] + [str(int(row['q18']))])
    if father in df_ed.index:
        row['q19'] = highest_education(father)
    row['q20'] = 1
    if father in df_hh.index:
        row['q22'] = df_hh.loc[father]['q05y']

df.drop(columns=['q12', 'q18'], inplace=True)

# %% [markdown]
# Comparing distributions

# %%
# First analyze NA distributions across all columns
print("Initial NA Percentages:")
for col in df.columns:
    if col not in ['set', 'subjective_poverty']:  # Skip these metadata columns
        train_na = df[df['set'] == 'train'][col].isna().mean()
        test_na = df[df['set'] == 'test'][col].isna().mean()
        
        # Only print if there are any NAs in either set
        if train_na > 0 or test_na > 0:
            print(f"\n{col}:")
            print(f"Train NA%: {train_na:.2%}")
            print(f"Test NA%: {test_na:.2%}")
            
            # Also show value distribution for columns with NAs
            print("\nValue distribution (excluding NAs):")
            print(df[col].value_counts(normalize=True).head())
# Out:
# Initial NA Percentages:
#
# q06_hh:
# Train NA%: 8.66%
# Test NA%: 0.00%
#
# Value distribution (excluding NAs):
# q06_hh
# 1.0    0.599294
# 5.0    0.333043
# 4.0    0.056562
# 2.0    0.008441
# 3.0    0.002661
# Name: proportion, dtype: float64
#
# q07_hh:
# Train NA%: 45.78%
# Test NA%: 13.19%
#
# Value distribution (excluding NAs):
# q07_hh
# 1.0    0.967308
# 2.0    0.032692
# Name: proportion, dtype: float64
#
# q08:
# Train NA%: 47.51%
# Test NA%: 16.79%
#
# Value distribution (excluding NAs):
# q08
# 2.0    0.443400
# 1.0    0.432756
# 3.0    0.053997
# 4.0    0.042654
# 5.0    0.010566
# Name: proportion, dtype: float64
#
# q13:
# Train NA%: 45.27%
# Test NA%: 8.02%
#
# Value distribution (excluding NAs):
# q13
# 2.0    0.377317
# 1.0    0.338621
# 3.0    0.208970
# 5.0    0.033062
# 4.0    0.017717
# Name: proportion, dtype: float64
#
# q14:
# Train NA%: 45.27%
# Test NA%: 8.02%
#
# Value distribution (excluding NAs):
# q14
# 2.0    0.524166
# 1.0    0.475834
# Name: proportion, dtype: float64
#
# q15:
# Train NA%: 71.52%
# Test NA%: 48.35%
#
# Value distribution (excluding NAs):
# q15
# 70.0    0.086975
# 80.0    0.075803
# 75.0    0.054165
# 78.0    0.049074
# 65.0    0.042144
# Name: proportion, dtype: float64
#
# q16:
# Train NA%: 73.75%
# Test NA%: 59.67%
#
# Value distribution (excluding NAs):
# q16
# 70.0    0.069170
# 65.0    0.056239
# 75.0    0.048450
# 60.0    0.046425
# 80.0    0.042530
# Name: proportion, dtype: float64
#
# q19:
# Train NA%: 40.83%
# Test NA%: 4.12%
#
# Value distribution (excluding NAs):
# q19
# 2.0    0.375868
# 1.0    0.310656
# 3.0    0.211323
# 5.0    0.041480
# 4.0    0.023182
# Name: proportion, dtype: float64
#
# q20:
# Train NA%: 40.83%
# Test NA%: 4.12%
#
# Value distribution (excluding NAs):
# q20
# 2.0    0.681778
# 1.0    0.318222
# Name: proportion, dtype: float64
#
# q21:
# Train NA%: 59.94%
# Test NA%: 29.84%
#
# Value distribution (excluding NAs):
# q21
# 70.0    0.077086
# 80.0    0.064877
# 75.0    0.053880
# 72.0    0.042377
# 78.0    0.042276
# Name: proportion, dtype: float64
#
# q22:
# Train NA%: 80.88%
# Test NA%: 74.29%
#
# Value distribution (excluding NAs):
# q22
# 70.0    0.078470
# 60.0    0.047557
# 65.0    0.045396
# 75.0    0.045396
# 80.0    0.043882
# Name: proportion, dtype: float64
#
# q04:
# Train NA%: 3.99%
# Test NA%: 2.92%
#
# Value distribution (excluding NAs):
# q04
# 1.0    0.545510
# 2.0    0.268722
# 6.0    0.124868
# 5.0    0.025254
# 4.0    0.015565
# Name: proportion, dtype: float64
#
# q05:
# Train NA%: 3.99%
# Test NA%: 2.92%
#
# Value distribution (excluding NAs):
# q05
# 4.0    0.339004
# 8.0    0.316380
# 3.0    0.087776
# 2.0    0.067959
# 1.0    0.050596
# Name: proportion, dtype: float64
#
# q06:
# Train NA%: 3.99%
# Test NA%: 2.92%
#
# Value distribution (excluding NAs):
# q06
# 2.0    0.397492
# 3.0    0.254472
# 1.0    0.134865
# 9.0    0.079183
# 0.0    0.068660
# Name: proportion, dtype: float64
#
# q07:
# Train NA%: 3.99%
# Test NA%: 2.92%
#
# Value distribution (excluding NAs):
# q07
# 0.0    0.524027
# 1.0    0.252894
# 2.0    0.140039
# 3.0    0.073658
# 4.0    0.009383
# Name: proportion, dtype: float64
#
# Q08:
# Train NA%: 3.99%
# Test NA%: 2.92%
#
# Value distribution (excluding NAs):
# Q08
# 2.0    0.755437
# 1.0    0.244563
# Name: proportion, dtype: float64
#
# Q09:
# Train NA%: 75.16%
# Test NA%: 99.03%
#
# Value distribution (excluding NAs):
# Q09
# 1.0    0.99265
# 2.0    0.00735
# Name: proportion, dtype: float64
#
# Q10:
# Train NA%: 99.83%
# Test NA%: 99.85%
#
# Value distribution (excluding NAs):
# Q10
# 2.0     0.560976
# 1.0     0.268293
# 13.0    0.073171
# 4.0     0.048780
# 8.0     0.024390
# Name: proportion, dtype: float64
#
# Q11:
# Train NA%: 28.82%
# Test NA%: 3.90%
#
# Value distribution (excluding NAs):
# Q11
# 13.0    0.647940
# 2.0     0.242890
# 4.0     0.042948
# 12.0    0.021126
# 1.0     0.020778
# Name: proportion, dtype: float64
#
# Q12:
# Train NA%: 75.34%
# Test NA%: 99.18%
#
# Value distribution (excluding NAs):
# Q12
# 1.0    0.563843
# 2.0    0.236048
# 6.0    0.161098
# 8.0    0.021131
# 5.0    0.012100
# Name: proportion, dtype: float64
#
# Q13:
# Train NA%: 75.34%
# Test NA%: 99.18%
#
# Value distribution (excluding NAs):
# Q13
# 2.0    0.184215
# 3.0    0.178617
# 1.0    0.162904
# 4.0    0.098971
# 9.0    0.082716
# Name: proportion, dtype: float64
#
# Q14:
# Train NA%: 3.99%
# Test NA%: 2.92%
#
# Value distribution (excluding NAs):
# Q14
# 2.0    0.752718
# 1.0    0.247282
# Name: proportion, dtype: float64
#
# Q15:
# Train NA%: 74.90%
# Test NA%: 98.88%
#
# Value distribution (excluding NAs):
# Q15
# 1.0    0.993617
# 2.0    0.006383
# Name: proportion, dtype: float64
#
# Q16:
# Train NA%: 99.84%
# Test NA%: 99.93%
#
# Value distribution (excluding NAs):
# Q16
# 13.0    0.555556
# 2.0     0.277778
# 1.0     0.138889
# 12.0    0.027778
# Name: proportion, dtype: float64
#
# Q17:
# Train NA%: 29.09%
# Test NA%: 4.05%
#
# Value distribution (excluding NAs):
# Q17
# 13.0    0.661871
# 2.0     0.235496
# 4.0     0.043453
# 12.0    0.016193
# 1.0     0.015727
# Name: proportion, dtype: float64
#
# Q18:
# Train NA%: 29.09%
# Test NA%: 4.05%
#
# Value distribution (excluding NAs):
# Q18
# 14.0    0.363467
# 18.0    0.283784
# 22.0    0.082421
# 10.0    0.063548
# 15.0    0.048404
# Name: proportion, dtype: float64
#
# Q19:
# Train NA%: 28.93%
# Test NA%: 3.97%
#
# Value distribution (excluding NAs):
# Q19
# 2.0    0.954894
# 1.0    0.045106
# Name: proportion, dtype: float64
#
# Q20:
# Train NA%: 96.55%
# Test NA%: 99.85%
#
# Value distribution (excluding NAs):
# Q20
# 2.0    0.740979
# 1.0    0.259021
# Name: proportion, dtype: float64
#
# Q21:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q21
# 1.0    0.615275
# 2.0    0.222163
# 6.0    0.135974
# 5.0    0.012134
# 8.0    0.008744
# Name: proportion, dtype: float64
#
# Q22:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q22
# 1.0    0.182905
# 2.0    0.179515
# 3.0    0.177552
# 8.0    0.083155
# 9.0    0.078694
# Name: proportion, dtype: float64
#
# Q23:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q23
# 1.0    0.967166
# 3.0    0.024625
# 2.0    0.008208
# Name: proportion, dtype: float64
#
# Q24:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q24
# 1.0    0.190935
# 0.0    0.156138
# 2.0    0.089757
# 0.5    0.078694
# 3.0    0.058173
# Name: proportion, dtype: float64
#
# Q25:
# Train NA%: 95.18%
# Test NA%: 99.55%
#
# Value distribution (excluding NAs):
# Q25
# 2.0    0.698895
# 1.0    0.301105
# Name: proportion, dtype: float64
#
# Q26:
# Train NA%: 75.11%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q26
# 0.0    0.886404
# 1.0    0.079428
# 2.0    0.015385
# 3.0    0.009302
# 5.0    0.005903
# Name: proportion, dtype: float64
#
# Q27:
# Train NA%: 75.11%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q27
# 10.0    0.204830
# 15.0    0.158318
# 20.0    0.157961
# 30.0    0.124866
# 5.0     0.114490
# Name: proportion, dtype: float64
#
# Q28:
# Train NA%: 75.11%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q28
# 1.0    0.776923
# 5.0    0.169767
# 4.0    0.048837
# 2.0    0.002326
# 7.0    0.001252
# Name: proportion, dtype: float64
#
# Q29:
# Train NA%: 94.53%
# Test NA%: 99.55%
#
# Value distribution (excluding NAs):
# Q29
# 20000.0    0.119415
# 30000.0    0.096669
# 0.0        0.090171
# 12000.0    0.085297
# 10000.0    0.075548
# Name: proportion, dtype: float64
#
# Q30:
# Train NA%: 94.53%
# Test NA%: 99.55%
#
# Value distribution (excluding NAs):
# Q30
# 2.0    0.977254
# 1.0    0.022746
# Name: proportion, dtype: float64
#
# Q31:
# Train NA%: 99.88%
# Test NA%: 100.00%
#
# Value distribution (excluding NAs):
# Q31
# 20000.0     0.214286
# 0.0         0.142857
# 15000.0     0.142857
# 100000.0    0.107143
# 10000.0     0.071429
# Name: proportion, dtype: float64
#
# Q32:
# Train NA%: 75.11%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q32
# 2.0    0.76458
# 1.0    0.23542
# Name: proportion, dtype: float64
#
# Q33:
# Train NA%: 75.37%
# Test NA%: 99.03%
#
# Value distribution (excluding NAs):
# Q33
# 0.0         0.661967
# 10000.0     0.048988
# 5000.0      0.028380
# 20000.0     0.023138
# 100000.0    0.020246
# Name: proportion, dtype: float64
#
# Q34:
# Train NA%: 75.37%
# Test NA%: 99.03%
#
# Value distribution (excluding NAs):
# Q34
# 0.0        0.708966
# 10000.0    0.068330
# 20000.0    0.043022
# 15000.0    0.035973
# 5000.0     0.023861
# Name: proportion, dtype: float64
#
# Q35:
# Train NA%: 75.37%
# Test NA%: 99.03%
#
# Value distribution (excluding NAs):
# Q35
# 30000.0    0.131598
# 50000.0    0.126537
# 40000.0    0.118040
# 20000.0    0.063268
# 35000.0    0.053868
# Name: proportion, dtype: float64
#
# Q36:
# Train NA%: 75.38%
# Test NA%: 99.03%
#
# Value distribution (excluding NAs):
# Q36
# 0.0        0.755515
# 10000.0    0.067812
# 20000.0    0.046112
# 5000.0     0.022242
# 15000.0    0.020434
# Name: proportion, dtype: float64
#
# Q37:
# Train NA%: 75.37%
# Test NA%: 99.03%
#
# Value distribution (excluding NAs):
# Q37
# 10000.0    0.277165
# 0.0        0.171940
# 20000.0    0.128187
# 5000.0     0.103056
# 15000.0    0.077924
# Name: proportion, dtype: float64
#
# Q38:
# Train NA%: 75.37%
# Test NA%: 99.03%
#
# Value distribution (excluding NAs):
# Q38
# 0.0          0.815980
# 100000.0     0.018619
# 200000.0     0.013738
# 50000.0      0.012292
# 1000000.0    0.011931
# Name: proportion, dtype: float64
#
# Q39:
# Train NA%: 75.37%
# Test NA%: 99.03%
#
# Value distribution (excluding NAs):
# Q39
# 0.0        0.741457
# 20000.0    0.051709
# 10000.0    0.040318
# 30000.0    0.038872
# 50000.0    0.029832
# Name: proportion, dtype: float64
#
# Q40:
# Train NA%: 75.37%
# Test NA%: 99.03%
#
# Value distribution (excluding NAs):
# Q40
# 0.0        0.751085
# 10000.0    0.065618
# 20000.0    0.032357
# 30000.0    0.024946
# 5000.0     0.019704
# Name: proportion, dtype: float64
#
# Q41:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q41
# 60000.0     0.043540
# 50000.0     0.043005
# 70000.0     0.039436
# 100000.0    0.036046
# 40000.0     0.035867
# Name: proportion, dtype: float64
#
# Q42:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q42
# 2.0    0.532477
# 1.0    0.453605
# 3.0    0.013919
# Name: proportion, dtype: float64
#
# Q43:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q43
# 1.0    0.807994
# 2.0    0.192006
# Name: proportion, dtype: float64
#
# Q44:
# Train NA%: 95.21%
# Test NA%: 99.85%
#
# Value distribution (excluding NAs):
# Q44
# 2.0    0.564126
# 1.0    0.291822
# 3.0    0.105019
# 4.0    0.039033
# Name: proportion, dtype: float64
#
# Q45:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q45
# 1.0    0.570307
# 2.0    0.429693
# Name: proportion, dtype: float64
#
# Q46:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q46
# 2.0    0.745896
# 1.0    0.254104
# Name: proportion, dtype: float64
#
# Q47:
# Train NA%: 93.64%
# Test NA%: 100.00%
#
# Value distribution (excluding NAs):
# Q47
# 20000.0    0.167135
# 30000.0    0.160112
# 40000.0    0.078652
# 25000.0    0.064607
# 0.0        0.061798
# Name: proportion, dtype: float64
#
# Q48:
# Train NA%: 93.64%
# Test NA%: 100.00%
#
# Value distribution (excluding NAs):
# Q48
# 2.0    0.398876
# 4.0    0.257725
# 3.0    0.188202
# 1.0    0.155197
# Name: proportion, dtype: float64
#
# Q49:
# Train NA%: 95.28%
# Test NA%: 100.00%
#
# Value distribution (excluding NAs):
# Q49
# 20000.0    0.163671
# 30000.0    0.123936
# 15000.0    0.102176
# 25000.0    0.076632
# 10000.0    0.054872
# Name: proportion, dtype: float64
#
# Q50:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q50
# 2.0    0.966453
# 1.0    0.033547
# Name: proportion, dtype: float64
#
# Q51:
# Train NA%: 99.17%
# Test NA%: 99.93%
#
# Value distribution (excluding NAs):
# Q51
# 1.0    0.691489
# 2.0    0.244681
# 3.0    0.053191
# 4.0    0.010638
# Name: proportion, dtype: float64
#
# Q52:
# Train NA%: 99.17%
# Test NA%: 99.93%
#
# Value distribution (excluding NAs):
# Q52
# 3.0    0.558511
# 2.0    0.250000
# 1.0    0.180851
# 4.0    0.010638
# Name: proportion, dtype: float64
#
# Q53:
# Train NA%: 99.17%
# Test NA%: 99.93%
#
# Value distribution (excluding NAs):
# Q53
# 2.0    0.776596
# 3.0    0.164894
# 4.0    0.031915
# 1.0    0.021277
# 6.0    0.005319
# Name: proportion, dtype: float64
#
# Q54:
# Train NA%: 99.17%
# Test NA%: 99.93%
#
# Value distribution (excluding NAs):
# Q54
# 1.0    0.968085
# 2.0    0.031915
# Name: proportion, dtype: float64
#
# Q55:
# Train NA%: 99.19%
# Test NA%: 99.93%
#
# Value distribution (excluding NAs):
# Q55
# 5000.0     0.181319
# 2000.0     0.175824
# 10000.0    0.109890
# 3000.0     0.109890
# 1000.0     0.076923
# Name: proportion, dtype: float64
#
# Q56:
# Train NA%: 99.19%
# Test NA%: 99.93%
#
# Value distribution (excluding NAs):
# Q56
# 10000.0    0.120879
# 20000.0    0.104396
# 40000.0    0.082418
# 30000.0    0.071429
# 12000.0    0.049451
# Name: proportion, dtype: float64
#
# Q57:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q57
# 2.0    0.951463
# 1.0    0.048537
# Name: proportion, dtype: float64
#
# Q58:
# Train NA%: 98.79%
# Test NA%: 100.00%
#
# Value distribution (excluding NAs):
# Q58
# 5000.0     0.316176
# 10000.0    0.198529
# 2000.0     0.180147
# 20000.0    0.080882
# 3000.0     0.066176
# Name: proportion, dtype: float64
#
# Q59:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q59
# 2.0    0.998929
# 1.0    0.001071
# Name: proportion, dtype: float64
#
# Q60:
# Train NA%: 99.97%
# Test NA%: 100.00%
#
# Value distribution (excluding NAs):
# Q60
# 2.0    0.500000
# 3.0    0.166667
# 1.0    0.166667
# 0.0    0.166667
# Name: proportion, dtype: float64
#
# Q61:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q61
# 2.0    0.9702
# 1.0    0.0298
# Name: proportion, dtype: float64
#
# Q62:
# Train NA%: 99.25%
# Test NA%: 100.00%
#
# Value distribution (excluding NAs):
# Q62
# 2.0    0.191617
# 5.0    0.185629
# 3.0    0.143713
# 1.0    0.143713
# 7.0    0.071856
# Name: proportion, dtype: float64
#
# Q63:
# Train NA%: 99.25%
# Test NA%: 100.00%
#
# Value distribution (excluding NAs):
# Q63
# 8.0     0.359281
# 1.0     0.257485
# 4.0     0.119760
# 2.0     0.095808
# 12.0    0.089820
# Name: proportion, dtype: float64
#
# Q64:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q64
# 2.0    0.98626
# 1.0    0.01374
# Name: proportion, dtype: float64
#
# Q65:
# Train NA%: 99.66%
# Test NA%: 100.00%
#
# Value distribution (excluding NAs):
# Q65
# 80000.0     0.142857
# 40000.0     0.077922
# 500000.0    0.077922
# 450000.0    0.051948
# 200000.0    0.051948
# Name: proportion, dtype: float64
#
# Q66:
# Train NA%: 75.05%
# Test NA%: 98.95%
#
# Value distribution (excluding NAs):
# Q66
# 4.0    0.312455
# 5.0    0.204497
# 3.0    0.176124
# 2.0    0.165596
# 6.0    0.078158
# Name: proportion, dtype: float64

# %% [markdown]
# sorting differences

# %%
# Calculate NA percentage differences between train and test sets
na_differences = {}
for col in df.columns:
    if col not in ['set', 'subjective_poverty']:
        train_na = df[df['set'] == 'train'][col].isna().mean()
        test_na = df[df['set'] == 'test'][col].isna().mean()
        difference = abs(train_na - test_na)
        
        if difference > 0:  # Only store columns with differences
            na_differences[col] = {
                'difference': difference,
                'train_na': train_na,
                'test_na': test_na
            }

# Sort and display columns by discrepancy
sorted_differences = sorted(na_differences.items(), 
                          key=lambda x: x[1]['difference'], 
                          reverse=True)

print("NA Percentage Discrepancies (Train vs Test):")
print("\nColumn | Train NA% | Test NA% | Difference")
print("-" * 50)
for col, stats in sorted_differences:
    print(f"{col:15} | {stats['train_na']:8.2%} | {stats['test_na']:7.2%} | {stats['difference']:.2%}")
# Out:
# NA Percentage Discrepancies (Train vs Test):
#
# Column | Train NA% | Test NA% | Difference
# --------------------------------------------------
# q13             |   45.27% |   8.02% | 37.25%
# q14             |   45.27% |   8.02% | 37.25%
# q19             |   40.83% |   4.12% | 36.71%
# q20             |   40.83% |   4.12% | 36.71%
# q07_hh          |   45.78% |  13.19% | 32.59%
# q08             |   47.51% |  16.79% | 30.72%
# q21             |   59.94% |  29.84% | 30.11%
# Q17             |   29.09% |   4.05% | 25.04%
# Q18             |   29.09% |   4.05% | 25.04%
# Q19             |   28.93% |   3.97% | 24.96%
# Q11             |   28.82% |   3.90% | 24.92%
# Q15             |   74.90% |  98.88% | 23.98%
# Q21             |   75.05% |  98.95% | 23.90%
# Q22             |   75.05% |  98.95% | 23.90%
# Q23             |   75.05% |  98.95% | 23.90%
# Q24             |   75.05% |  98.95% | 23.90%
# Q41             |   75.05% |  98.95% | 23.90%
# Q42             |   75.05% |  98.95% | 23.90%
# Q43             |   75.05% |  98.95% | 23.90%
# Q45             |   75.05% |  98.95% | 23.90%
# Q46             |   75.05% |  98.95% | 23.90%
# Q50             |   75.05% |  98.95% | 23.90%
# Q57             |   75.05% |  98.95% | 23.90%
# Q59             |   75.05% |  98.95% | 23.90%
# Q61             |   75.05% |  98.95% | 23.90%
# Q64             |   75.05% |  98.95% | 23.90%
# Q66             |   75.05% |  98.95% | 23.90%
# Q09             |   75.16% |  99.03% | 23.86%
# Q12             |   75.34% |  99.18% | 23.84%
# Q13             |   75.34% |  99.18% | 23.84%
# Q26             |   75.11% |  98.95% | 23.84%
# Q27             |   75.11% |  98.95% | 23.84%
# Q28             |   75.11% |  98.95% | 23.84%
# Q32             |   75.11% |  98.95% | 23.84%
# Q33             |   75.37% |  99.03% | 23.66%
# Q34             |   75.37% |  99.03% | 23.66%
# Q35             |   75.37% |  99.03% | 23.66%
# Q38             |   75.37% |  99.03% | 23.66%
# Q40             |   75.37% |  99.03% | 23.66%
# Q37             |   75.37% |  99.03% | 23.65%
# Q39             |   75.37% |  99.03% | 23.65%
# Q36             |   75.38% |  99.03% | 23.65%
# q15             |   71.52% |  48.35% | 23.17%
# q16             |   73.75% |  59.67% | 14.08%
# q06_hh          |    8.66% |   0.00% | 8.66%
# q22             |   80.88% |  74.29% | 6.60%
# Q47             |   93.64% | 100.00% | 6.36%
# Q48             |   93.64% | 100.00% | 6.36%
# Q29             |   94.53% |  99.55% | 5.02%
# Q30             |   94.53% |  99.55% | 5.02%
# Q49             |   95.28% | 100.00% | 4.72%
# Q44             |   95.21% |  99.85% | 4.64%
# Q25             |   95.18% |  99.55% | 4.37%
# Q20             |   96.55% |  99.85% | 3.30%
# Q58             |   98.79% | 100.00% | 1.21%
# q04             |    3.99% |   2.92% | 1.06%
# q05             |    3.99% |   2.92% | 1.06%
# q06             |    3.99% |   2.92% | 1.06%
# q07             |    3.99% |   2.92% | 1.06%
# Q08             |    3.99% |   2.92% | 1.06%
# Q14             |    3.99% |   2.92% | 1.06%
# Q51             |   99.17% |  99.93% | 0.76%
# Q52             |   99.17% |  99.93% | 0.76%
# Q53             |   99.17% |  99.93% | 0.76%
# Q54             |   99.17% |  99.93% | 0.76%
# Q62             |   99.25% | 100.00% | 0.75%
# Q63             |   99.25% | 100.00% | 0.75%
# Q55             |   99.19% |  99.93% | 0.73%
# Q56             |   99.19% |  99.93% | 0.73%
# Q65             |   99.66% | 100.00% | 0.34%
# Q31             |   99.88% | 100.00% | 0.12%
# Q16             |   99.84% |  99.93% | 0.08%
# Q60             |   99.97% | 100.00% | 0.03%
# Q10             |   99.83% |  99.85% | 0.02%

# %% [markdown]
# Feature engineering

# %%
#df['highest_ed'] = [highest_education(ind) for ind, row in df.iterrows()]
#df.drop(columns=['q04', 'q05'], inplace=True)

# Replace Q05
df['years_primary'] = [row['q05'] if row['q04'] == 1 else 0 for i,row in df.iterrows()]
df['years_secondary'] = [row['q05'] if row['q04'] == 2 else 0 for i,row in df.iterrows()]
df['years_vocational'] = [row['q05'] if row['q04'] in [3,4,5] else 0 for i,row in df.iterrows()]
df['years_uni'] = [row['q05'] if row['q04'] in [6,7] else 0 for i,row in df.iterrows()]
df['years_postgrad'] = [row['q05'] if row['q04'] in [8,9,10,11] else 0 for i,row in df.iterrows()]
df.drop(columns=['q05'], inplace=True)
#df.drop(columns=['q05', 'Q13', 'Q22'], inplace=True)

# Combine postsecondary for q4
#df['q04'] = [min(row['q04'], 6.0) for i,row in df.iterrows()]
# ^ TRY WITHOUT THIS ERR(1)

# combine age (year and month) into single number
# Note: Maybe change this to categorical for logistic regression? Seems unlikely
#       to be linear
df['age'] = df['q05y'] + df['q05m'] / 12
df.drop(columns=['q05y', 'q05m'], inplace=True)
def age_group(age):
    if (age < 12):
        return 0
    elif (age < 18):
        return 1
    elif (age < 30):
        return 2
    elif (age < 40):
        return 3
    elif (age < 50):
        return 4
    elif (age < 60):
        return 5
    else:
        return 6
df['age_group'] = [age_group(age) for age in df['age']]
#df.drop(columns=['age'], inplace=True)

print(df['age_group'].value_counts())

# following commented out because we removed the q24 column

"""
# turn q24_ed (distance from school) into categorical
def distance_category(dist):
  if dist == 0:
    return 0
  if dist < 1:
    return 1
  if dist < 2:
    return 2
  if dist < 3:
    return 3
  if dist < 4:
    return 4
  if dist < 5:
    return 5
  if dist < 10:
    return 6
  if dist < 50:
    return 7
  if dist < 100:
    return 8
  return 9

df['dist_from_school'] = [distance_category(dist) for dist in df['Q24']]
df.drop(columns=['Q24'], inplace=True)
"""
# Out:
# age_group
# 2    4957
# 6    4038
# 5    3555
# 4    3548
# 1    2915
# 3    2786
# 0    1941
# Name: count, dtype: int64
# "\n# turn q24_ed (distance from school) into categorical\ndef distance_category(dist):\n  if dist == 0:\n    return 0\n  if dist < 1:\n    return 1\n  if dist < 2:\n    return 2\n  if dist < 3:\n    return 3\n  if dist < 4:\n    return 4\n  if dist < 5:\n    return 5\n  if dist < 10:\n    return 6\n  if dist < 50:\n    return 7\n  if dist < 100:\n    return 8\n  return 9\n\ndf['dist_from_school'] = [distance_category(dist) for dist in df['Q24']]\ndf.drop(columns=['Q24'], inplace=True)\n"

# %% [markdown]
# One hot encoding for categorical variables + cleanup

# %%
categorical = ['q01', 'q02', 'q06','Q11', 'Q17','q03_hh', 'q06_hh', 'q13', 'q19',
               'age_group', 'psu']#'highest_ed']

# following commented out because we removed most columns
"""categorical = ['q04', 'q06', 'Q10', 'Q11', 'Q12', 'Q16', 'Q17',
               'Q21', 'Q23', 'Q28', 'Q42', 'Q44', 'Q48', 'Q52',
               'Q53', 'Q63', 'Q66', 'q03_hh', 'q06_hh', 'q13', 'q19',
               'dist_from_school']
"""

# create onehot df and add it to the original df
for col in categorical:
    new_onehot = pd.get_dummies(df[col], prefix = col)
    df = pd.concat([df, new_onehot],axis=1)

# drop the original categorical
df.drop(columns=categorical, inplace=True)

# useless columns (q04_hh is date of birth, redundant with q05 which is age)
# hhid would be useful, but no observations in the train and test set share a hhid
df.drop(columns=['q04_hh', 'hhid'], inplace=True)

# %%
# making parent age death categorical

# First modify the parent age categorization to use string labels instead of numbers
def categorize_parent_age(is_alive, age):
    if pd.isna(age):
        if is_alive == 1:  
            return 'alive'
        else:  
            return 'deceased_unknown'
    else:  
        if age < 40:
            return 'died_under_40'
        elif age < 50:
            return 'died_40_50'
        elif age < 60:
            return 'died_50_60'
        elif age < 70:
            return 'died_60_70'
        else:
            return 'died_over_70'

# Apply categorization
df['mother_status'] = df.apply(
    lambda row: categorize_parent_age(
        row['q14'] if 'q14' in row else row['q11'],
        row['q15']
    ), axis=1
)

df['father_status'] = df.apply(
    lambda row: categorize_parent_age(
        row['q20'] if 'q20' in row else row['q17'],
        row['q21']
    ), axis=1
)

# One-hot encode the new categorical columns
mother_dummies = pd.get_dummies(df['mother_status'], prefix='mother')
father_dummies = pd.get_dummies(df['father_status'], prefix='father')

# Add the dummy columns to the dataframe and drop the original columns
df = pd.concat([df, mother_dummies, father_dummies], axis=1)
df.drop(columns=['mother_status', 'father_status', 'q15', 'q21'], inplace=True)

# Print value distributions to verify
#print("\nMother age category distribution:")
#print(df['q15'].value_counts(normalize=True))
#print("\nFather age category distribution:")
#print(df['q21'].value_counts(normalize=True))

# %% [markdown]
# Normalization + train test split + filling in remaining NAs

# %%
# For real test set:

#df_train = df.join(y_train, how='inner').sample(frac=1)
#df_test = df[df['set'] == 'test']

# %%
#----------------------------------------------------------------------------------------------------------------------
# For development test set:
df_final = df.join(y_train, how='inner')
df_train,df_test = model_selection.train_test_split(df_final, train_size = 0.8)
#----------------------------------------------------------------------------------------------------------------------

same_cols = []

means = {}
stds = {}

# standardization
for col in df_train:
    if col not in ['psu_hh_idcode', 'subjective_poverty', 'set'] :
        if df_train[col].std() == 0 or df_test[col].std() == 0:
            print("all same", col)
            same_cols.append(col)
            continue
        means[col] = df_train[col].mean()
        stds[col] = df_train[col].std()
        df_train[col] = (df_train[col] - means[col]) / stds[col]
        df_test[col] = (df_test[col] - means[col]) / stds[col]

# drop columns that are all the same (i.e. give no info) in train or test set
df_train.drop(columns=same_cols, inplace=True)
df_test.drop(columns=same_cols, inplace=True)

# fill remaining NAs with 0 (i.e. mean)
# maybe change this part to be smarter
df_train.fillna(0, inplace=True)
df_test.fillna(0, inplace=True)
# Out:
# all same q10
# all same Q10
# all same Q15
# all same Q19
# all same Q20
# all same Q25
# all same Q30
# all same Q46
# all same Q50
# all same Q57
# all same Q59
# all same Q61
# all same years_postgrad
# all same q06_8.0
# all same q06_10.0
# all same q06_11.0
# all same Q11_5.0
# all same Q11_7.0
# all same Q11_9.0
# all same Q11_11.0
# all same Q17_6.0
# all same Q17_7.0
# all same Q17_9.0
# all same Q17_11.0
# all same q03_hh_3
# all same q03_hh_5
# all same q03_hh_6
# all same q03_hh_10
# all same q03_hh_11
# all same q03_hh_12
# all same q03_hh_13
# all same q03_hh_14
# all same q13_8.0
# all same age_group_0
# all same psu_9
# all same psu_13
# all same psu_19
# all same psu_26
# all same psu_33
# all same psu_46
# all same psu_49
# all same psu_51
# all same psu_54
# all same psu_55
# all same psu_56
# all same psu_59
# all same psu_70
# all same psu_71
# all same psu_74
# all same psu_75
# all same psu_93
# all same psu_97
# all same psu_100
# all same psu_102
# all same psu_109
# all same psu_110
# all same psu_111
# all same psu_116
# all same psu_117
# all same psu_119
# all same psu_120
# all same psu_133
# all same psu_137
# all same psu_143
# all same psu_144
# all same psu_148
# all same psu_150
# all same psu_164
# all same psu_166
# all same psu_168
# all same psu_169
# all same psu_175
# all same psu_177
# all same psu_180
# all same psu_190
# all same psu_192
# all same psu_193
# all same psu_201
# all same psu_204
# all same psu_209
# all same psu_210
# all same psu_211
# all same psu_219
# all same psu_222
# all same psu_224
# all same psu_226
# all same psu_229
# all same psu_230
# all same psu_231
# all same psu_244
# all same psu_249
# all same psu_254
# all same psu_256
# all same psu_258
# all same psu_266
# all same psu_271
# all same psu_272
# all same psu_274
# all same psu_276
# all same psu_278
# all same psu_279
# all same psu_281
# all same psu_282
# all same psu_283
# all same psu_292
# all same psu_295
# all same psu_300
# all same psu_301
# all same psu_303
# all same psu_305
# all same psu_311
# all same psu_313
# all same psu_317
# all same psu_318
# all same psu_319
# all same psu_327
# all same psu_335
# all same psu_336
# all same psu_337
# all same psu_338
# all same psu_339
# all same psu_341
# all same psu_344
# all same psu_347
# all same psu_355
# all same psu_359
# all same psu_360
# all same psu_363
# all same psu_366
# all same psu_370
# all same psu_373
# all same psu_380
# all same psu_382
# all same psu_384
# all same psu_391
# all same psu_399
# all same psu_401
# all same psu_403
# all same psu_405
# all same psu_406
# all same psu_409
# all same psu_410
# all same psu_415
# all same psu_416
# all same psu_417
# all same psu_424
# all same psu_432
# all same psu_437
# all same psu_438
# all same psu_440
# all same psu_449
# all same psu_457
# all same psu_460
# all same psu_463
# all same psu_466
# all same psu_468
# all same psu_469
# all same psu_470
# all same psu_474
# all same psu_475
# all same psu_478
# all same psu_479
# all same psu_480
# all same psu_488
# all same psu_497
# all same psu_499
# all same psu_501
# all same psu_506
# all same psu_507
# all same psu_512
# all same psu_517
# all same psu_520
# all same psu_529
# all same psu_530
# all same psu_531
# all same psu_546
# all same psu_552
# all same psu_558
# all same psu_579
# all same psu_582
# all same psu_583
# all same psu_601
# all same psu_604
# all same psu_621
# all same psu_622
# all same psu_623
# all same psu_632
# all same psu_647
# all same psu_648
# all same psu_656
# all same psu_659
# all same psu_662
# all same psu_664
# all same psu_669
# all same psu_670
# all same psu_673
# all same psu_676
# all same psu_677
# all same psu_681
# all same psu_690
# all same psu_693
# all same psu_695
# all same psu_700
# all same psu_704
# all same psu_724
# all same psu_726
# all same psu_727
# all same psu_732
# all same psu_738
# all same psu_740
# all same psu_744
# all same psu_759
# all same psu_764
# all same psu_765
# all same psu_773
# all same psu_777
# all same psu_781
# all same psu_785
# all same psu_787
# all same psu_790
# all same psu_794
# all same psu_799
# all same psu_801
# all same psu_802
# all same psu_806
# all same psu_813
# all same psu_823
# all same psu_825
# all same psu_831
# all same psu_832
# all same psu_833

# %% [markdown]
# Fit + eval for logistic regression, KNN, random forest, boosting

# %%
import numpy as np
import scipy.ndimage

def smooth(p):
    # Ensure the probabilities sum to 1
    p = p / np.sum(p)

    # Identify the index and value of the maximum probability
    max_idx = np.argmax(p)
    p_max = p[max_idx]

    # Set K as (N / 2) squared, where N is the length of p
    N = len(p)
    K = (N / 2) ** 2

    # Compute sigma_squared based on the maximum probability
    sigma_squared = K * (1 - p_max)

    # If sigma_squared is zero, no smoothing is needed
    if sigma_squared == 0:
        return p  # Return the original probabilities

    # Compute Gaussian weights centered at max_idx
    indices = np.arange(N)
    gaussian_weights = np.exp(-((indices - max_idx) ** 2) / (2 * sigma_squared))

    # Apply the Gaussian weights to the probabilities
    p_new = p * gaussian_weights

    # Normalize the new probabilities so they sum to 1
    p_new /= np.sum(p_new)

    return p_new

for idx, item in df_train.iterrows():
  if item["set"] == "test":
    print("misrepresented")

X = df_train.drop(columns=["subjective_poverty", "set"])
y = df_train["subjective_poverty"]


#development test set
X_test = df_test.drop(columns=["subjective_poverty", "set"])
y_test = df_test["subjective_poverty"]

# actual test set
#X_test = df_test.drop(columns=["set"])

# %% [markdown]
# logistic regression with l2 penalty

# %%
# First fit the model
lr = linear_model.LogisticRegressionCV(
    cv=5,
    penalty='l2',
    scoring='neg_log_loss',
    max_iter=1000,
    n_jobs=-1,
    random_state=42
)
lr.fit(X, y)

# Get the mean scores and standard errors
mean_scores = -np.mean(lr.scores_[list(lr.scores_.keys())[0]], axis=0)  # Negative because we used neg_log_loss
std_scores = np.std(lr.scores_[list(lr.scores_.keys())[0]], axis=0)

# Find the minimum score and its index
min_score_idx = np.argmin(mean_scores)
min_score = mean_scores[min_score_idx]

# Find the largest C value whose score is within one std err of the minimum
threshold = min_score + std_scores[min_score_idx]
valid_indices = np.where(mean_scores <= threshold)[0]
one_se_idx = valid_indices[0]  # Take the largest C value (first index due to C being in descending order)
optimal_c = lr.C_[one_se_idx]

# Refit with the one-SE C value
lr_final = linear_model.LogisticRegression(
    C=optimal_c,
    penalty='l2',
    max_iter=1000,
    random_state=42
)

probs_lr = lr_final.fit(X,y).predict_proba(X_test)
probs_lr_smooth = [smooth(i) for i in probs_lr]


#development test set
#print(metrics.log_loss(y_test, probs_lr, labels = ['subjective_poverty_' + str(i) for i in range(1,11)]))
#print(metrics.log_loss(y_test, probs_lr_smooth, labels = ['subjective_poverty_' + str(i) for i in range(1,11)]))

# %%
#development test set
print(metrics.log_loss(y_test, probs_lr, labels = [i for i in range(1,11)]))
print(metrics.log_loss(y_test, probs_lr_smooth, labels = [i for i in range(1,11)]))
# Out:
# 1.8297594273007733
# 1.803719694435607

# %% [markdown]
# knn

# %%
# Find optimal k using cross-validation
k_range = range(1, 501, 10)  # Test k values from 1 to 500 in steps of 10
cv_scores = []

for k in k_range:
    knn = neighbors.KNeighborsClassifier(n_neighbors=k, weights='distance')
    scores = model_selection.cross_val_score(knn, X, y, cv=5, scoring='neg_log_loss')
    cv_scores.append(-scores.mean())  # Negative because we want to minimize log loss

# Find the optimal k
optimal_k = k_range[np.argmin(cv_scores)]

# Train final model with optimal k
knn = neighbors.KNeighborsClassifier(n_neighbors=optimal_k, weights='distance')
probs_knn = knn.fit(X,y).predict_proba(X_test)

probs_knn_smooth = [smooth(i) for i in probs_knn]

# Print results
print(f"Optimal k: {optimal_k}")
print(f"Log loss (unsmoothed): {metrics.log_loss(y_test, probs_knn)}")
print(f"Log loss (smoothed): {metrics.log_loss(y_test, probs_knn_smooth)}")

# Optionally plot CV results
plt.figure(figsize=(10, 6))
plt.plot(k_range, cv_scores)
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Cross-Validation Log Loss')
plt.title('KNN Cross-Validation Results')
plt.show()
# Out:
# Optimal k: 481
# Log loss (unsmoothed): 1.9368038405865198
# Log loss (smoothed): 1.948231642786216

# %%
print(metrics.log_loss(y_test, probs_knn, labels = [i for i in range(1,11)]))
print(metrics.log_loss(y_test, probs_knn_smooth, labels = [i for i in range(1,11)]))
# Out:
# 1.9368038405865198
# 1.948231642786216

# %% [markdown]
# random forest

# %%
og_rf = ensemble.RandomForestClassifier(random_state=42, criterion="log_loss")
probs_rf = og_rf.fit(X,y).predict_proba(X_test)
probs_rf_smooth = [smooth(i) for i in probs_rf]
print(metrics.log_loss(y_test, probs_rf, labels = [i for i in range(1,11)]))
print(metrics.log_loss(y_test, probs_rf_smooth, labels = [i for i in range(1,11)]))
# Out:
# 2.585712565681241
# 2.6036819111056513

# %% [markdown]
# random forest with hyperparameter tuning

# %%
# Define parameter grid
param_grid = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Create RandomForest with CV
rf_cv = model_selection.GridSearchCV(
    ensemble.RandomForestClassifier(random_state=42, criterion="log_loss"),
    param_grid=param_grid,
    cv=5,
    scoring='neg_log_loss',
    n_jobs=-1
)

# Fit and predict
rf_cv.fit(X, y)
probs_rf = rf_cv.predict_proba(X_test)
probs_rf_smooth = [smooth(i) for i in probs_rf]

# Print best parameters and score
print("Best parameters:", rf_cv.best_params_)
print("Best CV score:", -rf_cv.best_score_)  # Negative because of neg_log_loss
# Out:
# Best parameters: {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 400}
# Best CV score: 1.9208768735380795

# %% [markdown]
# gradient boosting

# %%
gb = ensemble.GradientBoostingClassifier(random_state=42)
probs_gb = gb.fit(X,y).predict_proba(X_test)
probs_gb_smooth = [smooth(i) for i in probs_gb]

# development test set
#print(metrics.log_loss(y_test, probs_gb, labels = ['subjective_poverty_' + str(i) for i in range(1,11)]))
#print(metrics.log_loss(y_test, probs_gb_smooth, labels = ['subjective_poverty_' + str(i) for i in range(1,11)]))

# %%
# development test set
print(metrics.log_loss(y_test, probs_gb, labels = [i for i in range(1,11)]))
print(metrics.log_loss(y_test, probs_gb_smooth, labels = [i for i in range(1,11)]))
# Out:
# 2.0155678696786956
# 2.065257651178156

# %% [markdown]
# XGboost with hyperparameter tuning with regularization
# - WARNING: THIS TAKES A LONG TIME TO RUN

# %%
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint

# Adjust the labels to be 0-based
y_zero_based = y - 1  # Subtract 1 from all labels to make them 0-based

# Parameter distributions (unchanged)
param_distributions = {
    'learning_rate': uniform(0.01, 0.3),
    'max_depth': randint(3, 10),
    'n_estimators': randint(100, 1000),
    'reg_alpha': uniform(0, 2),
    'reg_lambda': uniform(0, 2),
    'gamma': uniform(0, 5),
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4),
    'colsample_bylevel': uniform(0.6, 0.4),
    'min_child_weight': randint(1, 7),
    'max_delta_step': randint(0, 10),
    'scale_pos_weight': uniform(0.8, 0.4)
}

# Base model with adjusted num_class
xgb_base = xgb.XGBClassifier(
    objective='multi:softprob',
    num_class=10,  # Still 10 classes, but now 0-9
    random_state=42,
    tree_method='hist',
    grow_policy='lossguide'
)

# Random Search with adjusted y values
random_search = RandomizedSearchCV(
    estimator=xgb_base,
    param_distributions=param_distributions,
    n_iter=50,
    scoring='neg_log_loss',
    cv=5,
    verbose=1,
    n_jobs=-1,
    random_state=42
)

# Fit with adjusted y values
random_search.fit(X, y_zero_based)

# When making predictions, add 1 back to get original scale
probs_xgb = random_search.predict_proba(X_test)
probs_xgb_smooth = [smooth(i) for i in probs_xgb]

# Evaluate using original 1-10 labels
print("\nFinal model performance:")
print(f"Log loss (unsmoothed): {metrics.log_loss(y_test, probs_xgb, labels=[i for i in range(1,11)])}")
print(f"Log loss (smoothed): {metrics.log_loss(y_test, probs_xgb_smooth, labels=[i for i in range(1,11)])}")
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:25] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:25] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:25] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:25] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:25] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:26] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:26] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:26] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:33] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:33] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:34] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:34] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:34] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:36] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:36] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:36] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:44] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:44] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:48] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:55] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:56] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:58] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:58] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:06:58] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:00] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:00] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:00] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:07] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:19] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:21] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:21] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:21] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:22] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:22] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:23] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:29] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:34] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:34] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:35] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:35] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:36] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:36] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:41] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:41] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:41] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:42] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:42] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:43] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:57] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:07:58] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:01] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:02] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:02] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:02] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:03] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:03] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:13] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:16] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:16] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:20] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:20] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:21] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:21] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:21] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:23] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:27] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:27] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:31] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:32] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:33] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:34] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:34] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:34] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:34] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:35] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:37] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:39] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:40] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:55] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:57] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:57] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:57] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:57] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:57] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:58] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:08:59] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:06] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:06] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:07] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:07] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:07] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:13] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:14] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:16] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:18] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:20] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:20] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:21] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:21] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:24] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:25] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:27] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:28] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:38] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:38] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:38] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:38] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:42] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:50] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:52] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:09:53] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:02] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:02] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:03] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:03] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:06] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:13] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:15] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:19] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:25] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:28] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:28] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:29] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:30] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:32] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:35] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:39] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:44] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:50] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:53] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:54] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:54] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:54] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:55] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:58] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:58] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:58] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:59] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:10:59] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:11:00] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:11:03] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:11:06] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ...
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:21] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:21] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:23] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:25] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:30] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:32] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:34] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:39] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:41] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:54] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:54] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:54] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:54] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:54] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:54] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:58] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:24:59] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:03] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:03] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:03] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:03] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:06] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:13] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:13] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:13] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:20] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:20] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:21] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:27] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:30] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:34] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:34] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:34] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:34] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:35] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:36] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:42] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:45] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:48] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:58] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:59] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:59] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:25:59] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:26:00] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:26:03] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:26:07] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:26:27] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Final model performance:
# Log loss (unsmoothed): 1.870619344250183
# Log loss (smoothed): 1.859501779147393

# %%
# Plot feature importance
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
xgb.plot_importance(random_search.best_estimator_, max_num_features=20)
plt.title('Feature Importance (Top 20)')
plt.show()

# %%
# Really simple one
overall_probs = y_train.value_counts() / sum(y_train.value_counts())
y_pred = pd.DataFrame(index=X_test.index, columns = ['subjective_poverty_' + str(i) for i in range(1,11)])
for i in range(1,11):
    y_pred['subjective_poverty_' + str(i)] = overall_probs['subjective_poverty_' + str(i)]
#print(metrics.log_loss(y_test, y_pred, labels = ['subjective_poverty_' + str(i) for i in range(1,11)]))

# %%
stack = ensemble.StackingClassifier([('logistic CV', lr_final), ('KNN', knn), ("XGboost", random_search.best_estimator_)])
stack_fit = stack.fit(X,y)

#development test set
probs_stack = stack_fit.predict_proba(X_test)
probs_stack_smooth = [smooth(i) for i in probs_stack]

#real test set
#out_df = pd.DataFrame(index=df_test.index, columns = ['subjective_poverty_' + str(i) for i in range(1,11)], data=probs_stack)

#  print(len(out_df))
#out_df.to_csv("probs_2.csv")
# Out:
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:35:09] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:35:20] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:35:27] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:35:33] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:35:40] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/sahal/miniconda3/envs/stat441-kaggle/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [15:35:46] WARNING: /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d9k8pmaj4_/croot/xgboost-split_1724073758172/work/src/learner.cc:740:
# Parameters: { "scale_pos_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
scores = model_selection.cross_val_score(stack, X, y, cv=5, scoring='neg_log_loss', n_jobs=5)
scores_smooth = [smooth(i) for i in scores]
print(f"Scores: {scores}, Mean scores: {scores.mean()}")
print(f"Scores: {scores_smooth}, Mean scores: {scores_smooth.mean()}")
